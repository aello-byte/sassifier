# %%
#env set-up
from dotenv import load_dotenv
import os

load_dotenv()

import pandas as pd
import pyarrow.parquet as pq
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_colwidth", 200)
sns.set(style="whitegrid")

# %%
df = pd.read_parquet("../data/raw/tscript-0000.parquet")

# %%
df.head()
# Out:
#       video_id                                 original_url  \
# 0  3TFGE7JrSW4  https://www.youtube.com/watch?v=3TFGE7JrSW4
# 1  7ewCFhx-ZPk  https://www.youtube.com/watch?v=7ewCFhx-ZPk
# 2  sCi0ALN7tzw  https://www.youtube.com/watch?v=sCi0ALN7tzw
# 3  V5Ye7180Ti4  https://www.youtube.com/watch?v=V5Ye7180Ti4
# 4  c3MAUv5rYVw  https://www.youtube.com/watch?v=c3MAUv5rYVw
#
#                                                                                                                                                                                                 transcript
# 0  I'd be like, "Guys don't want to date me cuz I'm a drag queen." And people would be like, "Would you date a drag queen?" I'm like, "Are you disgusting?" I'd rather have you steal my furniture than...
# 1  I'm Republican and you're Democratic ask me if I like orange juice or apple do I like orange or apple Mr Vance which do you prefer apple juice or orange juice well you know in my 18 years as a pro...
# 2  by the way you've been sitting here not a single piece of oil is on your face it's cuz I'm young how old are you 26 how old do you think I am mhm how old do you actually think I am well you know m...
# 3  sunshine on my shoulders can i say something i love the look of white knee socks it's so demented jan did you borrow my white knee socks peter you ever think about wearing brunette wigs i don't kn...
# 4  Have you ever seen that show Middle Ground? Abby was on one of them and there's this incredible love on the spectrum. Yeah, she's talking about haters. Listen, telling you haters. I know. There's ...
